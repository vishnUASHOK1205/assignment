# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import random
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Set the paths and parameters
animals_folder = '/content/drive/MyDrive/animals'  # Folder containing animal-named subfolders
animal_names_file = '/content/name of the animals.txt'  # File containing animal names
image_size = (150, 150)
batch_size = 64
num_classes = 90
num_epochs = 50

# Load the animal names from the file
animal_names = pd.read_csv(animal_names_file, header=None)[0].tolist()

# Create an ImageDataGenerator for data augmentation
data_generator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Load and augment the image dataset
train_datagen = data_generator.flow_from_directory(
    animals_folder,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Split the dataset into training and testing sets (70:30 split)
x_train, x_test, y_train, y_test = train_test_split(
    train_datagen[0][0], train_datagen[0][1],
    test_size=0.3, random_state=42
)

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(image_size[0], image_size[1], 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=batch_size,
    epochs=num_epochs
)

# Test the model
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Found 1480 images belonging to 90 classes.
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 4.6218 - accuracy: 0.0000e+00 - val_loss: 24.5339 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 1s 1s/step - loss: 21.9195 - accuracy: 0.0682 - val_loss: 22.0146 - val_accuracy: 0.1000
# Epoch 3/50
# 1/1 [==============================] - 1s 1s/step - loss: 21.2360 - accuracy: 0.0909 - val_loss: 14.8311 - val_accuracy: 0.0500
# Epoch 4/50
# 1/1 [==============================] - 1s 1s/step - loss: 14.6206 - accuracy: 0.0455 - val_loss: 12.3466 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 1/1 [==============================] - 2s 2s/step - loss: 11.9025 - accuracy: 0.0227 - val_loss: 10.7205 - val_accuracy: 0.0500
# Epoch 6/50
# 1/1 [==============================] - 2s 2s/step - loss: 9.9711 - accuracy: 0.0682 - val_loss: 9.8293 - val_accuracy: 0.0500
# Epoch 7/50
# ...

# %%
import os
import random
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Set the paths and parameters
animals_folder = '/content/drive/MyDrive/animals'  # Folder containing animal-named subfolders
animal_names_file = '/content/name of the animals.txt'  # File containing animal names
image_size = (150, 150)
batch_size = 64
num_classes = 90
num_epochs = 50

# Load the animal names from the file
animal_names = pd.read_csv(animal_names_file, header=None)[0].tolist()

# Create an ImageDataGenerator for data augmentation
data_generator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Load and augment the image dataset
train_datagen = data_generator.flow_from_directory(
    animals_folder,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Split the dataset into training and testing sets (70:30 split)
x_train, x_test, y_train, y_test = train_test_split(
    train_datagen[0][0], train_datagen[0][1],
    test_size=0.3, random_state=42
)

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(image_size[0], image_size[1], 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=batch_size,
    epochs=num_epochs
)

# Test the model
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Found 1480 images belonging to 90 classes.
# Epoch 1/50
# 1/1 [==============================] - 4s 4s/step - loss: 4.4756 - accuracy: 0.0000e+00 - val_loss: 7.0844 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 2s 2s/step - loss: 7.2317 - accuracy: 0.0682 - val_loss: 5.3766 - val_accuracy: 0.0500
# Epoch 3/50
# 1/1 [==============================] - 2s 2s/step - loss: 5.9589 - accuracy: 0.0227 - val_loss: 4.4045 - val_accuracy: 0.0500
# Epoch 4/50
# 1/1 [==============================] - 2s 2s/step - loss: 4.5554 - accuracy: 0.0455 - val_loss: 4.0553 - val_accuracy: 0.0500
# Epoch 5/50
# 1/1 [==============================] - 2s 2s/step - loss: 3.4603 - accuracy: 0.1818 - val_loss: 4.0164 - val_accuracy: 0.0500
# Epoch 6/50
# 1/1 [==============================] - 2s 2s/step - loss: 3.6555 - accuracy: 0.2273 - val_loss: 3.9184 - val_accuracy: 0.0500
# Epoch 7/50
# ...
